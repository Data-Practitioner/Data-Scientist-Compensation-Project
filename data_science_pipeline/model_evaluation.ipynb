# %% [markdown]
# # Predictive Modeling -  Model Evaluation

# %%
# Capturing all algorithms in a list for dataframe.
algorithm = ['Multiple Linear Regression', 'Support Vector Regression', 'Polinomial Vector Regression', 
             'Decision Tree Regression', 'Random Forest Regression', 'Logistic Regression', 
             'Gradient Boosting Regression', 'XGBoost Regression', 'LGBM Regression', 
             'CatBoost Regression', 'Stochastic Gradient Descent Regression', 'Kernel Ridge Regression', 
             'Elastic Net Regression', 'Bayesian Ridge Regression']

# Capturing all evaluation metrics in a list for dataframe.
r_square = [r_square_mlr, r_square_svr, r_square_pvr, r_square_dtr, r_square_rfr, r_square_lgr, r_square_gbr,
            r_square_xgbr, r_square_lgbmr, r_square_cbr, r_square_sgdr, r_square_krr, r_square_enr, r_square_brr]

rmse = [rmse_mlr, rmse_svr, rmse_pvr, rmse_dtr, rmse_rfr, rmse_lgr, rmse_gbr,
        rmse_xgbr, rmse_lgbmr, rmse_cbr, rmse_sgdr, rmse_krr, rmse_enr, rmse_brr]

mse = [mse_mlr, mse_svr, mse_pvr, mse_dtr, mse_rfr, mse_lgr, mse_gbr,
        mse_xgbr, mse_lgbmr, mse_cbr, mse_sgdr, mse_krr, mse_enr, mse_brr]

mae = [mae_mlr, mae_svr, mae_pvr, mae_dtr, mae_rfr, mae_lgr, mae_gbr,
        mae_xgbr, mae_lgbmr, mae_cbr, mae_sgdr, mae_krr, mae_enr, mae_brr]

mape = [mape_mlr, mape_svr, mape_pvr, mape_dtr, mape_rfr, mape_lgr, mape_gbr,
        mape_xgbr, mape_lgbmr, mape_cbr, mape_sgdr, mape_krr, mape_enr, mape_brr]

# Adding all the data into dataframe.
model_evaluation_df = pd.DataFrame({'algorithm': algorithm, 'r_square': r_square, 'rmse': rmse, 
                                    'mse': mse, 'mae': mae, 'mape': mape})

# Consolidating all data into csv file.
model_evaluation_df.to_csv("stackoverflow_ml_model_evaluation_metrics.csv", index=False)

# Print all algorithm evaluation metric.
model_evaluation_df.sort_values(by=['r_square'], ascending=False)
# Out:
#                                  algorithm  r_square          rmse  \
# 2             Polinomial Vector Regression  0.841713  21233.120128
# 3                 Decision Tree Regression  0.841713  21233.120128
# 7                       XGBoost Regression  0.813790  23029.916772
# 9                      CatBoost Regression  0.755679  26379.817883
# 4                 Random Forest Regression  0.725595  27956.809959
# 8                          LGBM Regression  0.480538  38465.209499
# 1                Support Vector Regression  0.421618      0.760514
# 6             Gradient Boosting Regression  0.372312  42282.755222
# 0               Multiple Linear Regression  0.189922  48034.654185
# 13               Bayesian Ridge Regression  0.186499  48136.023587
# 10  Stochastic Gradient Descent Regression  0.180699  48307.340914
# 12                  Elastic Net Regression  0.108737  50384.194945
# 5                      Logistic Regression  0.013879  52997.614733
# ...

# %% [markdown]
# # Analysis on Predictive Modeling
#
# Decision Tree Regression model is performing better than all other algorithms. It has the highest R Square and lowest RMSE, MAE, MSE, and MAPE.
#
# ![image.png](attachment:image.png)
